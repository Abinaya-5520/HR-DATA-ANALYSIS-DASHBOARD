# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinaya-5520/HR-DATA-ANALYSIS-DASHBOARD/blob/main/Abinaya_Python_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("enter your name")
age=int(input("enter your age"))
print("my name is",name, "i am ",age ,"years old")
# Out:
# enter your namenineetha
# enter your age21
# my name is nineetha i am  21 years old

# %%
name=input("enter your name")
age=int(input("enter your age"))
a=age+3
print("hi",name,"you will be",a,"in 3 years")
# Out:
# enter your namenineetha
# enter your age21
# hi nineetha you will be 24 in 3 years

# %%
text="python"
print(text[0])
print(text[4])
print(text[2:])
print(text[::-1])
print(text[-1:-7:-1])
# Out:
# p
# o
# thon
# nohtyp
# nohtyp

# %%
text=input("enter the word ")
print(text[::-1])
print(text[-1:-7:-1])
# Out:
# enter the word python
# nohtyp
# nohtyp

# %%
text = input("enter the word : ")
text = text.lower()
print(text)
rev=(text[::-1])
if(rev==text):
  print("palindrome")
else:
  print("not a palindrome")
# Out:
# enter the word : MaDam
# madam
# palindrome

# %%
text="ss briyani"
text2=(text.replace("ss","rr"))
print(text2)
# Out:
# rr briyani
